# %%
from google.colab import drive

ROOT = '/content/drive'
progetto_web_scraping = '/MyDrive/UNI_SGI/III Anno/Statitica Spaziale e Ambientale/Progetto'

print(ROOT)

drive.mount(ROOT)
# Out:
# /content/drive
# Mounted at /content/drive

# %%
# %ls
# Out:
# drive/  sample_data/

# %%
print(ROOT+progetto_web_scraping)
# Out:
# /content/drive/MyDrive/UNI_SGI/III Anno/Statitica Spaziale e Ambientale/Progetto

# %%
# Out:
# [Errno 2] No such file or directory: 'drive/'
# /content/drive
# MyDrive/  Shareddrives/
